# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import kaggle

# %%
# !kaggle datasets download -d brendan45774/test-file
# Out:
# ...
#   0%|          | 0.00/11.2k [00:00<?, ?B/s]
# 100%|##########| 11.2k/11.2k [00:00<00:00, 3.85MB/s]

# %%
#conda install git

# %%
#!unzip 'test-file.zip'

# %%
df = pd.read_csv(r"C:\Users\Universal\OneDrive\Data Science\Data Visualization\tested.csv")

# %%
df.shape
# Out:
# (418, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %%
sns.histplot(data=df['Age'])
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
plt.figure(figsize=(22, 10))
sns.boxplot(data=df, x='Survived', y='Age')
# Out:
# <Axes: xlabel='Survived', ylabel='Age'>

# %%
sns.histplot(data=df, x='Age', hue='Survived', multiple='stack', kde=True, log_scale=True
            )
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.histplot(data=df, x='Age', hue='Survived', multiple='stack', #kde=True, 
             log_scale=True)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.histplot(data=df, x='Sex', hue='Survived', multiple='stack', kde=True, #log_scale=True
            )
# Out:
# <Axes: xlabel='Sex', ylabel='Count'>

# %%
sns.lmplot(data=df, x='Age', y='Fare', hue='Survived', scatter_kws={"s": 70}, height=6)

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
df.shape
# Out:
# (418, 12)

# %%
# checking nulls
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
index_values = df.isnull().sum()

# %%
index_list = index_values.tolist()

# %%
df[df.Fare.isnull()]
# Out:
#      PassengerId  Survived  Pclass                Name   Sex   Age  SibSp  \
# 152         1044         0       3  Storey, Mr. Thomas  male  60.5      0
#
#      Parch Ticket  Fare Cabin Embarked
# 152      0   3701   NaN   NaN        S

# %%
fare_mean_c3 = df.Fare[df.Pclass == 3].mean()
df['Fare'].fillna(value=fare_mean_c3, inplace=True)

# %%
df[df.Fare.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df["Fare"][152]
# Out:
# 12.459677880184334

# %%
value = df.iloc[152]

# %%
print (value)
# Out:
# PassengerId                  1044
# Survived                        0
# Pclass                          3
# Name           Storey, Mr. Thomas
# Sex                          male
# Age                          60.5
# SibSp                           0
# Parch                           0
# Ticket                       3701
# Fare                    12.459678
# Cabin                         NaN
# Embarked                        S
# Name: 152, dtype: object
